# %% [markdown]
# # Create Latex Table of Picks
# ## Round 1

# %% [markdown]
# Information:
# Must have a row in the csv file of picks that has the Name as Results

# %%
import os
import numpy as np
import pandas as pd

# %%
year = 2019
rnd = 1

# %%
cd ../../2019
# Out:
# /Users/daviddeepwell/Documents/Hockey/Hockey Pool/Playoffs/2019

# %%
def shorten_team_name( team ):
    #Shorten the team name into it's acronym
    if team == 'Anaheim Ducks':
        return 'Anaheim'
    elif team == 'Arizona Coyotes':
        return 'Arizona'
    elif team == 'Boston Bruins':
        return 'Boston'
    elif team == 'Buffalo Sabres':
        return 'Buffalo'
    elif team == 'Calgary Flames':
        return 'Calgary'
    elif team == 'Carolina Hurricanes':
        return 'Carolina'
    elif team == 'Chicago Blackhawks':
        return 'Chicago'
    elif team == 'Colorado Avalanche':
        return 'Colorado'
    elif team == 'Columbus Blue Jackets':
        return 'Columbus'
    elif team == 'Dallas Stars':
        return 'Dallas'
    elif team == 'Detroit Red Wings':
        return 'Detroit'
    elif team == 'Edmonton Oilers':
        return 'Edmonton'
    elif team == 'Florida Panthers':
        return 'Florida'
    elif team == 'Los Angeles Kings':
        return 'Los Angeles'
    elif team == 'Minnesota Wild':
        return 'Minnesota'
    elif team == 'Montreal Canadiens':
        return 'Montreal'
    elif team == 'Nashville Predators':
        return 'Nashville'
    elif team == 'New Jersey Devils':
        return 'New Jersey'
    elif team == 'New York Islanders':
        return 'NY Islanders'
    elif team == 'New York Rangers':
        return 'NY Rangers'
    elif team == 'Ottawa Senators':
        return 'Ottawa'
    elif team == 'Philadelphia Flyers':
        return 'Philadelphia'
    elif team == 'Pittsburgh Penguins':
        return 'Pittsburgh'
    elif team == 'San Jose Sharks':
        return 'San Jose'
    elif team == 'St. Louis Blues':
        return 'St Louis'
    elif team == 'Tampa Bay Lightning':
        return 'Tampa Bay'
    elif team == 'Toronto Maple Leafs':
        return 'Toronto'
    elif team == 'Vancouver Canucks':
        return 'Vancouver'
    elif team == 'Vegas Golden Knights':
        return 'Vegas'
    elif team == 'Washington Capitals':
        return 'Washington'
    elif team == 'Winnipeg Jets':
        return 'Winnipeg'

# %%
def shorten_team_name( team ):
    #Shorten the team name into it's acronym
    if team == 'Anaheim Ducks':
        return 'ANA'
    elif team == 'Arizona Coyotes':
        return 'ARI'
    elif team == 'Boston Bruins':
        return 'BOS'
    elif team == 'Buffalo Sabres':
        return 'BUF'
    elif team == 'Calgary Flames':
        return 'CGY'
    elif team == 'Carolina Hurricanes':
        return 'CAR'
    elif team == 'Chicago Blackhawks':
        return 'CHI'
    elif team == 'Colorado Avalanche':
        return 'COL'
    elif team == 'Columbus Blue Jackets':
        return 'CBJ'
    elif team == 'Dallas Stars':
        return 'DAL'
    elif team == 'Detroit Red Wings':
        return 'DET'
    elif team == 'Edmonton Oilers':
        return 'EDM'
    elif team == 'Florida Panthers':
        return 'FLA'
    elif team == 'Los Angeles Kings':
        return 'LAK'
    elif team == 'Minnesota Wild':
        return 'MIN'
    elif team == 'Montreal Canadiens':
        return 'MTL'
    elif team == 'Nashville Predators':
        return 'NSH'
    elif team == 'New Jersey Devils':
        return 'NJD'
    elif team == 'New York Islanders':
        return 'NYI'
    elif team == 'New York Rangers':
        return 'NYR'
    elif team == 'Ottawa Senators':
        return 'OTT'
    elif team == 'Philadelphia Flyers':
        return 'PHI'
    elif team == 'Pittsburgh Penguins':
        return 'PIT'
    elif team == 'San Jose Sharks':
        return 'SJS'
    elif team == 'St Louis Blues':
        return 'STL'
    elif team == 'Tampa Bay Lightning':
        return 'TBL'
    elif team == 'Toronto Maple Leafs':
        return 'TOR'
    elif team == 'Vancouver Canucks':
        return 'VAN'
    elif team == 'Vegas Golden Knights':
        return 'VGK'
    elif team == 'Washington Capitals':
        return 'WSH'
    elif team == 'Winnipeg Jets':
        return 'WPG'

def stn( team ):
    return shorten_team_name( team )

# %%
# read csv file containing everyone picks
def read_round(year, rnd):
    fname = str(year)+' Friendly Playoff Pool Round '+str(rnd)+'.csv'    # read file
    if os.path.isfile(fname):    
        # if file exists, return a pandas table
        fdata = pd.read_csv(fname, sep=',')
        
        # make the names of people the index (the row name)
        fdata.index = fdata['Name:']

        # over write the column headers
        header = fdata.columns.values
        if rnd == 1:
            header[2:] = ['T1','G1','T2','G2','T3','G3','T4','G4','T5','G5','T6','G6','T7','G7','T8','G8','WCC','ECC','SCC']
            #header[2:] = ['T1','G1','T2','G2','T3','G3','T4','G4','T5','G5','T6','G6','T7','G7','T8','G8','SC','R']
        elif rnd == 2:
            header[2:] = ['T1','G1','T2','G2','T3','G3','T4','G4']
        elif rnd == 3:
            header[2:] = ['T1','G1','T2','G2']
        elif rnd == 4:
            header[2:] = ['T1','G1']
        fdata.columns = header

        # Remove 'Games' in games columns and cast numbers to integer
        N_series = 2**(4-rnd)      # number of series in round
        for ind in ['G'+str(x) for x in range(1,N_series+1)]:
            if fdata[ind].values[0] == '- Games':
                # set to an integer because arithemtic won't work later (a python thing)
                fdata[ind].values[0] = '0 Games'
            # remove and cast
            fdata[ind] = fdata[ind].map(lambda x: x.rstrip(' Games')).astype(int)
    else:
        # if file does NOT exists, return a string
        fdata = '-'
    return fdata

# %%
df = read_round(year, rnd)

# %%
df
# Out:
#                             Timestamp    Name:                   T1  G1  \
# Name:
# Results  2019/04/08 12:12:06 am GMT-5  Results         Dallas Stars   6
# Jack     2019/04/08 12:12:06 am GMT-5     Jack  Nashville Predators   5
# Josh     2019/04/08 10:30:41 am GMT-5     Josh  Nashville Predators   5
# Andrew    2019/04/08 6:30:16 pm GMT-5   Andrew         Dallas Stars   7
# David     2019/04/08 9:35:22 pm GMT-5    David  Nashville Predators   7
# Mark      2019/04/09 2:01:13 pm GMT-5     Mark  Nashville Predators   5
# Alita     2019/04/09 9:11:57 pm GMT-5    Alita         Dallas Stars   6
# Andre    2019/04/09 10:31:44 pm GMT-5    Andre         Dallas Stars   7
# Andres   2019/04/09 10:43:06 pm GMT-5   Andres  Nashville Predators   5
# Jeremy   2019/04/09 10:50:00 pm GMT-5   Jeremy  Nashville Predators   5
# Jon       2019/04/10 1:08:37 am GMT-5      Jon  Nashville Predators   5
# Kyle      2019/04/10 5:15:59 am GMT-5     Kyle  Nashville Predators   6
# ...

# %%
df2 = df.drop(['Results'])
table = df2.sort_values(by=['Name:'])

# %%
table['Name:']
# Out:
# Name:
# Alita        Alita
# Andre        Andre
# Andres      Andres
# Andrew      Andrew
# Anthony    Anthony
# Brian        Brian
# David        David
# Jack          Jack
# Jeremy      Jeremy
# Jon            Jon
# Josh          Josh
# Kollin      Kollin
# Kyle          Kyle
# Mark          Mark
# Michael    Michael
# Nathan      Nathan
# Ron            Ron
# Name: Name:, dtype: object

# %%
toplines = ["%----------------------------------------------------------------------------------------\n",
"%	Settings and packages\n",
"%----------------------------------------------------------------------------------------",
"\n",
"\\documentclass[10pt]{article}\n",
"\n",
"%\\usepackage[parfill]{parskip}    % Activate to begin paragraphs with an empty line rather than an indent\n",
"%\\usepackage{graphicx,caption,subcaption}\n",
"%\\usepackage{amsmath,amssymb,amsfonts,bm,mathrsfs}\n",
"%\\usepackage{fullpage}\n",
"%\\usepackage{array,enumerate}\n",
"%\\usepackage{cite,verbatim}\n",
"%\\usepackage{hyperref}\n",
"%\\usepackage{fancyhdr}				% together with the next line\n",
"%\\pagestyle{fancy}\n",
"\\usepackage{colortbl}\n",
"\\usepackage{multirow}\n",
"\\usepackage[table]{xcolor}\n",
"\\usepackage{ctable}\n",
"\\usepackage[landscape,margin=0.25in,legalpaper]{geometry}\n",
"\n",
"\\newcommand{\\mcn}[2]{\\multicolumn{#1}{l}{#2}}	\n",
"\\newcommand{\mccn}[2]{\multicolumn{#1}{c}{#2}}\n",
"\\newcommand{\\mcl}[1]{\\multicolumn{2}{l}{#1}}\n",
"\\newcommand{\\mclg}[1]{\\multicolumn{2}{l}{\\gr #1}}\n",
"\\newcommand{\\mcc}[1]{\\multicolumn{2}{c}{#1}}\n",
"\\newcommand{\\mccg}[1]{\\multicolumn{2}{c}{\\gr #1}}\n",
"\\newcommand{\\mr}[1]{\\multirow{-2}{*}{#1}}\n",
"\\definecolor{Gray}{gray}{0.90}\n",
"\\newcommand{\\gr}{\\cellcolor{Gray}}\n",
"\n",
"\\newcommand{\\thickline}{\specialrule{.1em}{.05em}{.05em} }\n",
"% column colours\n",
"\n",
"\\newcolumntype{g}{>{\columncolor{Gray}}l}\n",
"\\newcolumntype{w}{>{\columncolor{white}}l}\n",
"\n",
"\n",
"%\\usepackage{geometry}                		% See geometry.pdf to learn the layout options. There are lots.\n",
"%\\geometry{letterpaper}                   		% ... or a4paper or a5paper or ... \n",
"%\\geometry{landscape}                		% Activate for for rotated page geometry\n",
"\n",
"%----------------------------------------------------------------------------------------\n",
"%	Create new commands\n",
"%----------------------------------------------------------------------------------------\n",
"\n",
"% Commands are in LatexCommands.tex. New commands for this file only can be written here.\n",
"%\\input{/Applications/TeX/Latex_ancillary/LatexCommands.tex}\n",
"\n",
"\n",
"%----------------------------------------------------------------------------------------\n",
"%	Table\n",
"%----------------------------------------------------------------------------------------\n",
"\n",
"\\begin{document}\n",
"\n",
"\\thispagestyle{empty}\n",
"\n",
"{\\bf ",str(year)," Friendly Playoff Hockey Pool}\n",
"\n",
"\\begin{table}[h!]\n"
]

# %%
team_w1 = "Nashville Predators"
team_w2 = "Dallas Stars"
team_w3 = "Winnipeg Jets"
team_w4 = "St Louis Blues"
team_w5 = "Calgary Flames"
team_w6 = "Colorado Avalanche"
team_w7 = "San Jose Sharks"
team_w8 = "Vegas Golden Knights"
team_west = [team_w1,team_w2,team_w3,team_w4,team_w5,team_w6,team_w7,team_w8]

team_e1 = "Tampa Bay Lightning"
team_e2 = "Columbus Blue Jackets"
team_e3 = "Boston Bruins"
team_e4 = "Toronto Maple Leafs"
team_e5 = "Washington Capitals"
team_e6 = "Carolina Hurricanes"
team_e7 = "New York Islanders"
team_e8 = "Pittsburgh Penguins"
team_east = [team_e1,team_e2,team_e3,team_e4,team_e5,team_e6,team_e7,team_e8]

# %%
table_start = [
"\\begin{table}[!htb]\n",
"    \\begin{minipage}[t]{.27\linewidth}\n",
"    	{\\bf Points}\\\\\n",
"		\\begin{tabular}{l l}\n",
"			If correct team chosen:	& $15 - 2|P-A|$\\\\\n",
"			If incorrect team chosen:	& $P+A-8$\\\\\n",
"			Western/Eastern Conference champion:	& 20\\\\\n",
"			Stanley Cup champion:		& 20\\\\\n",
"			Where $P$ is the predicted number of games&\\\\\n",
"			Where $A$ is the actual number of games&\n",
"		\\end{tabular}\n",
"	\\end{minipage}\n",
"	\\begin{minipage}[t]{0.12\linewidth}\n",
"	\\qquad Correct team Points\\\\\n",
"	\\begin{tabular}{c l | c c c c }\n",
"		\\mccn{2}{} & \\mccn{4}{Predicted}\\\\\n",
"		& & 4 & 5 & 6 & 7\\\\\\cline{2-6}\n",
"		\\parbox[t]{2mm}{\\multirow{4}{*}{\\rotatebox[origin=c]{90}{Actual}}}&4 & 15 & 13 & 11 & 9\\\\\n",
"		&5 & 13 & 15 & 13 & 11\\\\\n",
"		&6 & 11 & 13 & 15 & 13\\\\\n",
"		&7 &  9 & 11 & 13 & 15\n",
"	\\end{tabular}\n",
"	\\end{minipage}\n",
"	\\begin{minipage}[t]{0.12\\linewidth}\n",
"	\\quad Incorrect team Points\\\\\n",
"	\\begin{tabular}{c l | c c c c }\n",
"		\\mccn{2}{} & \\mccn{4}{Predicted}\\\\\n",
"		& & 4 & 5 & 6 & 7\\\\\\cline{2-6}\n",
"		\\parbox[t]{2mm}{\\multirow{4}{*}{\\rotatebox[origin=c]{90}{Actual}}}&4 & 0 & 1 & 2 & 3\\\\\n",
"		&5 & 1 & 2 & 3 & 4\\\\\n",
"		&6 & 2 & 3 & 4 & 5\\\\\n",
"		&7 & 3 & 4 & 5 & 6\n",
"	\\end{tabular}\n",
"	\\end{minipage}\n",
"    \\begin{minipage}[t]{.45\linewidth}\n",
"    	{\\bf Number of picks per team:}\\\\\n"
]

N_series = 8
begintabular = "\\begin{tabular}{lc "+(N_series-1)*"| lc "+"}\n"

s1_num = ""
s2_num = ""
for ii in range(0,N_series,2):
    ts = table['T'+str(ii//2+1)].value_counts()
    if len(ts) == 1:
        ts2 = pd.Series(0, index=[team_west[ii+1]]) # will need to be careful here in the future
        ts = ts.append(ts2)
    s1_num += stn(team_west[ii])  +"&"+str(ts[team_west[ii]])  +"&"
    s2_num += stn(team_west[ii+1])+"&"+str(ts[team_west[ii+1]])+"&"
for ii in range(0,N_series,2):
    ts = table['T'+str(ii//2+N_series//2+1)].value_counts()
    if len(ts) == 1:
        ts2 = pd.Series(0, index=[team_east[ii+1]]) # will need to be careful here in the future
        ts = ts.append(ts2)
    s1_num += stn(team_east[ii])  +"&"+str(ts[team_east[ii]])  +"&"
    s2_num += stn(team_east[ii+1])+"&"+str(ts[team_east[ii+1]])+"&"

s1_num = s1_num[:-1]+"\\\\\n"
s2_num = s2_num[:-1]+"\\\\\n"
    
table_end = ["        \\end{tabular}\n",
"    \\end{minipage}\n",
"\\end{table}\n",
"\n",
"\\end{document}\n"
]

endlines = table_start + [begintabular + s1_num + s2_num] + table_end

# %%
N_people = len(table.index)
#N_people = 6
N_cols = 2*N_people + 1

begintabular = "\\begin{tabular}{l "
tnames = ""
w1 = shorten_team_name(team_w1)+(N_cols-1)*"&"+"\\\\\n"
w3 = shorten_team_name(team_w3)+(N_cols-1)*"&"+"\\\\\n"
w5 = shorten_team_name(team_w5)+(N_cols-1)*"&"+"\\\\\n"
w7 = shorten_team_name(team_w7)+(N_cols-1)*"&"+"\\\\\n"
e1 = shorten_team_name(team_e1)+(N_cols-1)*"&"+"\\\\\n"
e3 = shorten_team_name(team_e3)+(N_cols-1)*"&"+"\\\\\n"
e5 = shorten_team_name(team_e5)+(N_cols-1)*"&"+"\\\\\n"
e7 = shorten_team_name(team_e7)+(N_cols-1)*"&"+"\\\\\n"
w2 = shorten_team_name(team_w2)
w4 = shorten_team_name(team_w4)
w6 = shorten_team_name(team_w6)
w8 = shorten_team_name(team_w8)
e2 = shorten_team_name(team_e2)
e4 = shorten_team_name(team_e4)
e6 = shorten_team_name(team_e6)
e8 = shorten_team_name(team_e8)
wchamp = "Western"
echamp = "Eastern"
schamp = "Stanley Cup" # "Stanley Cup"
blank = (N_cols-1)*"&"+" \\\\\\hline\n"
blanker = (N_cols-1)*"&"+" \\\\\n"
for ii in range(N_people):
    if ii%2 == 0:
        begintabular += "g g "
        tnames += "&  \\mccg{"+table['Name:'][ii]+"}"
        wchamp += " & \\mclg{"+shorten_team_name(table.iloc[ii]["WCC"])+"}"
        echamp += " & \\mclg{"+shorten_team_name(table.iloc[ii]["ECC"])+"}"
        schamp += " & \\mclg{"+shorten_team_name(table.iloc[ii]["SCC"])+"}"
    else:
        begintabular += "w w "
        tnames += "&  \\mcc{"+table['Name:'][ii]+"}"
        wchamp += " & \\mcl{"+shorten_team_name(table.iloc[ii]["WCC"])+"}"
        echamp += " & \\mcl{"+shorten_team_name(table.iloc[ii]["ECC"])+"}"
        schamp += " & \\mcl{"+shorten_team_name(table.iloc[ii]["SCC"])+"}"
    w2 += " & \\mr{"+shorten_team_name(table.iloc[ii]["T1"])+"} & \\mr{"+str(table.iloc[ii]["G1"])+"}"
    w4 += " & \\mr{"+shorten_team_name(table.iloc[ii]["T2"])+"} & \\mr{"+str(table.iloc[ii]["G2"])+"}"
    w6 += " & \\mr{"+shorten_team_name(table.iloc[ii]["T3"])+"} & \\mr{"+str(table.iloc[ii]["G3"])+"}"
    w8 += " & \\mr{"+shorten_team_name(table.iloc[ii]["T4"])+"} & \\mr{"+str(table.iloc[ii]["G4"])+"}"
    e2 += " & \\mr{"+shorten_team_name(table.iloc[ii]["T5"])+"} & \\mr{"+str(table.iloc[ii]["G5"])+"}"
    e4 += " & \\mr{"+shorten_team_name(table.iloc[ii]["T6"])+"} & \\mr{"+str(table.iloc[ii]["G6"])+"}"
    e6 += " & \\mr{"+shorten_team_name(table.iloc[ii]["T7"])+"} & \\mr{"+str(table.iloc[ii]["G7"])+"}"
    e8 += " & \\mr{"+shorten_team_name(table.iloc[ii]["T8"])+"} & \\mr{"+str(table.iloc[ii]["G8"])+"}"
    
    
begintabular = begintabular[0:-1] + "}\n"
tabletitle = "\\rowcolor{black} \\mcn{"+str(N_cols)+"}{\\color{white}\\bf Round 1: Division Semi-Finals} \\\\\n"+"\\rowcolor{white}\\\\\n"
tnames += " \\\\\\thickline\n"
twest = "{\\bf West} "+(N_cols-1)*"&"+"\\\\\\hline\n"
teast = "{\\bf East} "+(N_cols-1)*"&"+"\\\\\\hline\n"
w2 += "\\\\\\hline\n"
w4 += "\\\\\\hline\n"
w6 += "\\\\\\hline\n"
w8 += "\\\\\\hline\n"
e2 += "\\\\\\hline\n"
e4 += "\\\\\\hline\n"
e6 += "\\\\\\hline\n"
e8 += "\\\\\\hline\n"
wchamp += "\\\\\n"
echamp += "\\\\\n"
schamp += "\n"

white = "\\rowcolor{white}\\\\\n"
champtitle = "\\rowcolor{black} \\mcn{"+str(N_cols)+"}{\\color{white}\\bf Conference Champions} \\\\\n"

table_start = begintabular + tabletitle + tnames
table_west = twest + w1 + w2 + blank + w3 + w4 + blank + w5 + w6 + blank + w7 + w8 + blanker
table_east = teast + e1 + e2 + blank + e3 + e4 + blank + e5 + e6 + blank + e7 + e8 + white
conf_champ = champtitle + wchamp + echamp + schamp
table_end = "\\end{tabular}\n"+"\\end{table}\n"+"\n"

middlelines = table_start + table_west + table_east + conf_champ + table_end

# %%
f = open("round"+str(rnd)+".tex","w+")
f.writelines(toplines)
f.writelines(middlelines)
f.writelines(endlines)
f.close()
